# %%
#Most important two features
# Which features correlates most with Y the possibility of having cancer 
import pandas as pd
#Pivot table for overall survival
df = pd.read_csv('Final2.csv')
corr = pd.pivot_table(df, columns=['cancer'])
#Get top 2 values 
bestDeathCorr2 = corr.iloc[:,0].sort_values(ascending=False).head(2)
bestDeathCorr2

#Least important two features
# Which features correlate most with Y the possibility of having cancer ?
import pandas as pd
#Pivot table for overall survival
df = pd.read_csv('Final2.csv')
corr = pd.pivot_table(df, columns=['cancer'])
#Get top 2 values 
bestDeathCorr2 = corr.iloc[:,0].sort_values(ascending=False).tail(2)
bestDeathCorr2

# Data Visualization
# Violin plot to visualize the most important two features with and without cancer
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('Final2.csv')
#X = data[['thickness', 'size', 'shape', 'adhesion', 'single', 'nucleoli','chromatin','mitosis']]
#y = data['y']
sns.catplot(data= data,x='thickness', y='single',hue='cancer',kind='violin',col='cancer',ci=None)

plt.show()
# Violin plot to visualize the least important two features with and without cancer
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('Final2.csv')
#X = data[['thickness', 'size', 'shape', 'adhesion', 'single', 'nucleoli','chromatin','mitosis']]
#y = data['y']
sns.catplot(data= data,x='nucleoli', y='mitosis',hue='cancer',kind='violin',col='cancer',ci=None,)
plt.show()

# Heatmap plot to visuliza the relationship between the variables
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the CSV file
data = pd.read_csv('Final2.csv')

# Select the relevant columns for the heatmap
columns = ['thickness', 'size', 'shape', 'adhesion', 'single', 'nuclei', 'nucleoli', 'chromatin', 'mitosis']
heatmap_data = data[columns]

# Calculate the correlation matrix
correlation_matrix = heatmap_data.corr()

# Create the colormap with blue and orange colors
cmap = sns.diverging_palette(240, 10, as_cmap=True)
# Create the heatmap using seaborn
sns.heatmap(correlation_matrix, cmap=cmap, annot=True, fmt='.2f')

# Add labels and title
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation Heatmap')

# Display the heatmap
plt.show()


# Pairplot to visualize the relationship between the variables
# Load the dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('Final2.csv')
X = data[['thickness', 'size', 'shape', 'adhesion', 'single','chromatin', 'nucleoli','nuclei','mitosis']]
y = data['cancer']

sns.pairplot(data=data, hue='cancer')
plt.show()
